# %%
# Import the script you just wrote
from paper_processing import process_papers

# List of URLs to process
urls = [
    "https://www.nber.org/system/files/working_papers/w33605/w33605.pdf",
    "https://www.nber.org/system/files/working_papers/w33594/w33594.pdf",
    "https://www.nber.org/system/files/working_papers/w33597/w33597.pdf",
    "https://www.nber.org/system/files/working_papers/w33564/w33564.pdf",
    "https://www.nber.org/system/files/working_papers/w33474/w33474.pdf",
    "https://www.nber.org/system/files/working_papers/w33442/w33442.pdf",
    "https://www.nber.org/system/files/working_papers/w29247/w29247.pdf",
    "https://www.nber.org/system/files/working_papers/w33076/w33076.pdf",
    "https://www.nber.org/system/files/working_papers/w31161/w31161.pdf",
    "https://www.nber.org/system/files/working_papers/w33566/w33566.pdf",
    "https://www.nber.org/system/files/working_papers/w32487/w32487.pdf",
    "https://www.nber.org/system/files/working_papers/w31222/w31222.pdf",
    "https://www.nber.org/system/files/working_papers/w24235/w24235.pdf",
    "https://www.nber.org/system/files/working_papers/w29996/w29996.pdf",
    "https://www.nber.org/system/files/working_papers/w28748/w28748.pdf",
    "https://www.nber.org/system/files/working_papers/w5352/w5352.pdf",
    "https://www.nber.org/system/files/working_papers/w28360/w28360.pdf",
    "https://www.nber.org/system/files/working_papers/w6691/w6691.pdf",
    "https://www.nber.org/system/files/working_papers/w8965/w8965.pdf",
    "https://www.nber.org/system/files/working_papers/w15315/w15315.pdf",
    "https://www.nber.org/system/files/working_papers/w13341/w13341.pdf",
    "https://www.nber.org/system/files/working_papers/w31607/w31607.pdf",
    "https://www.nber.org/system/files/working_papers/w19331/w19331.pdf"
    
]

# Process the papers and get the DataFrame
df = process_papers(urls)
df
# Out:
# Processing papers: 100%|██████████| 23/23 [02:06<00:00,  5.50s/paper]
#                                             Paper URL  \
# 0   https://www.nber.org/system/files/working_pape...
# 1   https://www.nber.org/system/files/working_pape...
# 2   https://www.nber.org/system/files/working_pape...
# 3   https://www.nber.org/system/files/working_pape...
# 4   https://www.nber.org/system/files/working_pape...
# 5   https://www.nber.org/system/files/working_pape...
# 6   https://www.nber.org/system/files/working_pape...
# 7   https://www.nber.org/system/files/working_pape...
# 8   https://www.nber.org/system/files/working_pape...
# 9   https://www.nber.org/system/files/working_pape...
# 10  https://www.nber.org/system/files/working_pape...
# 11  https://www.nber.org/system/files/working_pape...
# 12  https://www.nber.org/system/files/working_pape...
# 13  https://www.nber.org/system/files/working_pape...
# 14  https://www.nber.org/system/files/working_pape...
# 15  https://www.nber.org/system/files/working_pape...
# 16  https://www.nber.org/system/files/working_pape...
# 17  https://www.nber.org/system/files/working_pape...
# 18  https://www.nber.org/system/files/working_pape...
# 19  https://www.nber.org/system/files/working_pape...
# 20  https://www.nber.org/system/files/working_pape...
# 21  https://www.nber.org/system/files/working_pape...
# 22  https://www.nber.org/system/files/working_pape...
#
#                                        Title_Abstract  \
# 0   NBER WORKING PAPER SERIES\nTHE VALUE OF WORKER...
# 1   NBER WORKING PAPER SERIES\nOPTIMAL FORMULA INS...
# 2   NBER WORKING PAPER SERIES\nSEWERS AND URBANIZA...
# 3   NBER WORKING PAPER SERIES\nMETHANE ABATEMENT C...
# 4   NBER WORKING PAPER SERIES\nMISSPECIFICATION-RO...
# 5   NBER WORKING PAPER SERIES\nINSTITUTIONS, TECHN...
# 6   NBER WORKING PAPER SERIES\nHARMS OF AI\nDaron ...
# 7   NBER WORKING PAPER SERIES\nAI AND FINANCE\nAnd...
# 8   NBER WORKING PAPER SERIES\nGENERATIVE AI AT WO...
# 9   NBER WORKING PAPER SERIES\nA QUEST FOR AI KNOW...
# 10  NBER WORKING PAPER SERIES\nTHE SIMPLE MACROECO...
# 11  NBER WORKING PAPER SERIES\nGENERATIVE AI AND F...
# 12  NBER WORKING PAPER SERIES\nAI AND JOBS: THE RO...
# 13  NBER WORKING PAPER SERIES\nAI ADOPTION IN A CO...
# 14  NBER WORKING PAPER SERIES\nSCIENCE AS A PUBLIC...
# 15  IJOPC ! TACIJjO WG201ILCCbibpwiA pc dnocq iiup...
# 16  NBER WORKING PAPER SERIES\nCOVID-19 DISRUPTION...
# 17
# 18  NBER WORKING PAPER SERIES\nSTUDYING OURSELVES:...
# 19  NBER WORKING PAPER SERIES\nSPECIFIC AND GENERA...
# 20  NBER WORKING PAPER SERIES\nTHE CAUSAL EFFECT O...
# 21  NBER WORKING PAPER SERIES\nBIASED SURVEYS\nLuc...
# 22  NBER WORKING PAPER SERIES\nLEAVING BOYS BEHIND...
#
#                                            Conclusion
# 0   of wages. Our results situate the value of con...
# 1   outcome and the employer-sponsored insurance c...
# 2   The economic logic of cities is simple. We are...
# 3   19 \n REFERENCES  \n \nAgerton, Mark, Gilbert,...
# 4   This Version: February 5, 2025 42\nFigure 6: P...
# 5   new sources of red tape—intended to make a tra...
# 6   example as well. To understand these, let us c...
# 7   corporate finance decisions. For a recent stud...
# 8   7 Conclusion\nAdvancements in AI technologies ...
# 9   strategies but leads to reduced novelty as sci...
# 10  affected groups, because AI-exposed tasks are ...
# 11  V. Conclusion\nMarket prices indicate that the...
# 12  5 increase sufficiently to offset the labor -s...
# 13  the opposite may be the case with the returns ...
# 14  3 uses across three public domains. Our first ...
# 15
# 16  REFERENCES \nAlon, Titan, Doepke, Matthias, Ol...
# 17
# 18  9continuation rate for associate professors at...
# 19  5 References\nAdams, James D., Grant C. Black,...
# 20  4In addition to collecting detailed background...
# 21  incentive to “stand out” from the crowd, then ...
# 22  smoking and alcohol binging, but also school m...

# %%
import os
import getpass
from openai import OpenAI

# Prompt the user to securely enter their OpenAI API key
api_key = getpass.getpass(prompt="Enter your OpenAI API key: ")

# Initialize the OpenAI client with the provided API key
client = OpenAI(api_key=api_key)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/gj/3jxft49n0z7g7bhnsdpk_lmr0000gn/T/ipykernel_1211/3111327796.py in <module>
#       1 import os
#       2 import getpass
# ----> 3 from openai import OpenAI
#       4
#       5 # Prompt the user to securely enter their OpenAI API key
#
# ImportError: cannot import name 'OpenAI' from 'openai' (/opt/anaconda3/lib/python3.9/site-packages/openai/__init__.py)

# %%
research_question = """Research Question:

How do AI tools like ChatGPT, Copilot, and DeepSeek impact the research productivity and efficiency of 
Monash University academics in conducting literature reviews and data analysis?

Methodology:
Host a workshop for the faculty demonstrating relevant tools 
then conduct a survey and follow-up interviews with 
Monash University academics who use AI tools in their research workflow. 
Measure productivity changes through self-reported data on time spent on literature reviews,
data analysis, and overall research output. Analyze this data to assess improvements in efficiency and the 
perceived value of AI tools in academic research tasks."""

# %%
# Import the processing function from the Python file
from meta_analysis_processing import process_papers_in_parallel

# Assume you have a client variable (for example, OpenAI client) and a DataFrame `df` loaded with your paper data.
# Define chunk size, number of workers, and temperature
chunk_size = 1
n_workers = 25
temperature = 0  # Set your desired temperature

# Call the function with the new temperature setting
final_df = process_papers_in_parallel(df, client, chunk_size=chunk_size, n_workers=n_workers, temperature=temperature)

# Display the final processed DataFrame
final_df
# Out:
# Processing chunks in parallel: 100%|████████████| 23/23 [00:16<00:00,  1.44it/s]
#                                             Paper URL  \
# 0   https://www.nber.org/system/files/working_pape...
# 1   https://www.nber.org/system/files/working_pape...
# 2   https://www.nber.org/system/files/working_pape...
# 3   https://www.nber.org/system/files/working_pape...
# 4   https://www.nber.org/system/files/working_pape...
# 5   https://www.nber.org/system/files/working_pape...
# 6   https://www.nber.org/system/files/working_pape...
# 7   https://www.nber.org/system/files/working_pape...
# 8   https://www.nber.org/system/files/working_pape...
# 9   https://www.nber.org/system/files/working_pape...
# 10  https://www.nber.org/system/files/working_pape...
# 11  https://www.nber.org/system/files/working_pape...
# 12  https://www.nber.org/system/files/working_pape...
# 13  https://www.nber.org/system/files/working_pape...
# 14  https://www.nber.org/system/files/working_pape...
# 15  https://www.nber.org/system/files/working_pape...
# 16  https://www.nber.org/system/files/working_pape...
# 17  https://www.nber.org/system/files/working_pape...
# 18  https://www.nber.org/system/files/working_pape...
# 19  https://www.nber.org/system/files/working_pape...
# 20  https://www.nber.org/system/files/working_pape...
# 21  https://www.nber.org/system/files/working_pape...
# 22  https://www.nber.org/system/files/working_pape...
#
#                                        Title_Abstract  \
# 0   NBER WORKING PAPER SERIES\nTHE VALUE OF WORKER...
# 1   NBER WORKING PAPER SERIES\nOPTIMAL FORMULA INS...
# 2   NBER WORKING PAPER SERIES\nSEWERS AND URBANIZA...
# 3   NBER WORKING PAPER SERIES\nMETHANE ABATEMENT C...
# 4   NBER WORKING PAPER SERIES\nMISSPECIFICATION-RO...
# 5   NBER WORKING PAPER SERIES\nINSTITUTIONS, TECHN...
# 6   NBER WORKING PAPER SERIES\nHARMS OF AI\nDaron ...
# 7   NBER WORKING PAPER SERIES\nAI AND FINANCE\nAnd...
# 8   NBER WORKING PAPER SERIES\nGENERATIVE AI AT WO...
# 9   NBER WORKING PAPER SERIES\nA QUEST FOR AI KNOW...
# 10  NBER WORKING PAPER SERIES\nTHE SIMPLE MACROECO...
# 11  NBER WORKING PAPER SERIES\nGENERATIVE AI AND F...
# 12  NBER WORKING PAPER SERIES\nAI AND JOBS: THE RO...
# 13  NBER WORKING PAPER SERIES\nAI ADOPTION IN A CO...
# 14  NBER WORKING PAPER SERIES\nSCIENCE AS A PUBLIC...
# 15  IJOPC ! TACIJjO WG201ILCCbibpwiA pc dnocq iiup...
# 16  NBER WORKING PAPER SERIES\nCOVID-19 DISRUPTION...
# 17
# 18  NBER WORKING PAPER SERIES\nSTUDYING OURSELVES:...
# 19  NBER WORKING PAPER SERIES\nSPECIFIC AND GENERA...
# 20  NBER WORKING PAPER SERIES\nTHE CAUSAL EFFECT O...
# 21  NBER WORKING PAPER SERIES\nBIASED SURVEYS\nLuc...
# 22  NBER WORKING PAPER SERIES\nLEAVING BOYS BEHIND...
#
#                                            Conclusion Paper_ID  \
# 0   of wages. Our results situate the value of con...     P001
# 1   outcome and the employer-sponsored insurance c...     P001
# 2   The economic logic of cities is simple. We are...     P001
# 3   19 \n REFERENCES  \n \nAgerton, Mark, Gilbert,...     P001
# 4   This Version: February 5, 2025 42\nFigure 6: P...     P001
# 5   new sources of red tape—intended to make a tra...     P001
# 6   example as well. To understand these, let us c...     P001
# 7   corporate finance decisions. For a recent stud...     P001
# 8   7 Conclusion\nAdvancements in AI technologies ...     P001
# 9   The welfare benefits, however, extend far beyo...     P001
# 10  affected groups, because AI-exposed tasks are ...     P001
# 11  V. Conclusion\nMarket prices indicate that the...     P001
# 12  5 increase sufficiently to offset the labor -s...     P001
# 13  the opposite may be the case with the returns ...     P001
# 14  3 uses across three public domains. Our first ...     P001
# 15                                                        P001
# 16  REFERENCES \nAlon, Titan, Doepke, Matthias, Ol...     P001
# 17                                                        P001
# 18  9continuation rate for associate professors at...     P001
# 19  5 References\nAdams, James D., Grant C. Black,...     P001
# 20  4In addition to collecting detailed background...     P001
# 21  incentive to “stand out” from the crowd, then ...     P001
# 22  smoking and alcohol binging, but also school m...     P001
#
#                                             Author(s)  Year  \
# 0   Benjamin W. Arold, Elliott Ash, W. Bentley Mac...  2025
# 1                         Kirill Borusyak, Peter Hull  2025
# 2   Sean E. McCulloch, Matthew P. Schaelling, Matt...  2025
# 3   Joseph E. Aldy, Forest L. Reinhardt, Robert N....  2025
# 4           Oriol González-Casasús, Frank Schorfheide  2025
# 5                                      Daron Acemoglu  2025
# 6                                      Daron Acemoglu  2021
# 7                 Andrea L. Eisfeldt, Gregor Schubert  2024
# 8   Erik Brynjolfsson, Danielle Li, Lindsey R. Ray...  2023
# 9                                      Joshua S. Gans  2025
# 10                                     Daron Acemoglu  2024
# 11  Andrea L. Eisfeldt, Gregor Schubert, Miao Ben ...  2023
# 12                                       James Bessen  2018
# 13                                     Joshua S. Gans  2022
# 14  Yian Yin, Yuxiao Dong, Kuansan Wang, Dashun Wa...  2021
# 15                                            Unknown  1995
# 16  Tatyana Deryugina, Olga Shurchkov, Jenna E. St...  2021
# 17     David Card, Alexandre Mas, and Jesse Rothstein  2008
# 18                                Ronald G. Ehrenberg  2002
# 19  Carolin Haeussler, Lin Jiang, Jerry Thursby, M...  2009
# 20         Todd R. Stinebrickner, Ralph Stinebrickner  2007
# 21                          Luca Gemmi, Rosen Valchev  2023
# 22  Nicole M. Fortin, Philip Oreopoulos, Shelley P...  2013
#
#                                           Paper_Title  \
# 0   The Value of Worker Rights in Collective Barga...
# 1                         Optimal Formula Instruments
# 2     Sewers and Urbanization in the Developing World
# 3   Methane Abatement Costs in the Oil and Gas Ind...
# 4   Misspecification-Robust Shrinkage and Selectio...
# 5             Institutions, Technology and Prosperity
# 6                                         Harms of AI
# 7                                      AI and Finance
# 8                               Generative AI at Work
# 9                            A Quest for AI Knowledge
# 10                    The Simple Macroeconomics of AI
# 11                      Generative AI and Firm Values
# 12                    AI and Jobs: The Role of Demand
# 13                AI Adoption in a Competitive Market
# 14  Science as a Public Good: Public Use and Fundi...
# 15         The Economic Impact of AI on Labor Markets
# 16  COVID-19 Disruptions Disproportionately Affect...
# 17            Tipping and the Dynamics of Segregation
# 18      Studying Ourselves: The Academic Labor Market
# 19  Specific and General Information Sharing Among...
# 20  The Causal Effect of Studying on Academic Perf...
# 21                                     Biased Surveys
# 22  Leaving Boys Behind: Gender Disparities in Hig...
#
#                    Journal_Specific_ID  \
# 0    http://www.nber.org/papers/w33605
# 1    http://www.nber.org/papers/w33594
# 2         NBER Working Paper No. 33597
# 3    http://www.nber.org/papers/w33564
# 4         NBER Working Paper No. 33474
# 5         NBER Working Paper No. 33442
# 6         NBER Working Paper No. 29247
# 7         NBER Working Paper No. 33076
# 8         NBER Working Paper No. 31161
# 9         NBER Working Paper No. 33566
# 10        NBER Working Paper No. 32487
# 11        NBER Working Paper No. 31222
# 12   http://www.nber.org/papers/w24235
# 13        NBER Working Paper No. 29996
# 14        NBER Working Paper No. 28748
# 15         NBER Working Paper No. 5352
# 16        NBER Working Paper No. 28360
# 17                       10.3386/w6691
# 18         NBER Working Paper No. 8965
# 19        NBER Working Paper No. 15315
# 20   http://www.nber.org/papers/w13341
# 21  https://www.nber.org/papers/w31607
# 22   http://www.nber.org/papers/w19331
#
#                                     Research_Question  \
# 0   How do worker rights in collective bargaining ...
# 1   How can more powerful instruments be construct...
# 2   We investigate the effects of sewer access on ...
# 3   What are the marginal abatement cost functions...
# 4   How can we derive asymptotically unbiased esti...
# 5   How do institutions and technology interact to...
# 6   If AI continues to be deployed along its curre...
# 7   How does Generative AI affect firm values and ...
# 8   What are the impacts of generative AI tools on...
# 9   How does the introduction of artificial intell...
# 10  What are the macroeconomic implications of new...
# 11  What are the effects of recent advances in Gen...
# 12  How will artificial intelligence affect jobs o...
# 13  How does AI adoption affect competitive market...
# 14  How does public use and funding of science rel...
# 15  How does the introduction of AI technologies a...
# 16  How has the COVID-19 pandemic affected the gen...
# 17  How do tipping points affect the dynamics of s...
# 18  This paper addresses three academic labor mark...
# 19  What factors influence the willingness of acad...
# 20  Despite the large amount of attention that has...
# 21  We find evidence suggesting that surveys of pr...
# 22  What factors account for the gender difference...
#
#                                           Methodology  ...  \
# 0   The paper employs natural language processing ...  ...
# 1   The paper proposes an algorithm for constructi...  ...
# 2   The paper employs a quasi-experimental design ...  ...
# 3   The paper employs a synthesis of diverse metho...  ...
# 4   The paper employs Bayesian techniques to estim...  ...
# 5   The paper reviews existing literature and pres...  ...
# 6   The paper is a theoretical essay discussing po...  ...
# 7   Literature review and analysis of market react...  ...
# 8   The study employs a staggered introduction des...  ...
# 9   Theoretical analysis extending the framework o...  ...
# 10  The paper employs a task-based model to evalua...  ...
# 11  The study employs a quantitative analysis usin...  ...
# 12  The paper presents a theoretical model of dema...  ...
# 13  The paper uses a theoretical model to analyze ...  ...
# 14  The paper introduces a measurement framework i...  ...
# 15  The paper employs econometric analysis using r...  ...
# 16  The study employs a global survey distributed ...  ...
# 17  The paper uses a theoretical model to analyze ...  ...
# 18  The paper employs a quantitative analysis of s...  ...
# 19  The paper employs theoretical models and empir...  ...
# 20  The paper employs an Instrumental Variable est...  ...
# 21  The paper employs empirical analysis using dat...  ...
# 22  The paper employs a reweighted Oaxaca-Blinder ...  ...
#
#                                     Sample_Population  \
# 0   30,000 collective bargaining agreements from C...
# 1   The study uses a controlled environment where ...
# 2   Census tracts from Brazil, Colombia, South Afr...
# 3   Various studies and data from the oil and gas ...
# 4   Estimation sample from 1984:Q1 to 2006:Q4, wit...
# 5   Theoretical framework based on historical and ...
# 6   Theoretical analysis based on existing literat...
# 7   Analysis of firms across various industries po...
# 8   5,179 customer support agents across various l...
# 9   Theoretical model; no empirical data sample sp...
# 10  Theoretical model based on existing estimates ...
# 11  U.S. publicly traded companies, focusing on th...
# 12  Historical data from the textile, steel, and a...
# 13  Theoretical model; no empirical data sample sp...
# 14  Data includes 353,977 unique academic publicat...
# 15  Data from various sectors in the U.S. labor ma...
# 16  27,991 academics who completed the survey, wit...
# 17  Theoretical model; no specific sample size or ...
# 18  Data on faculty salaries from various public a...
# 19  Survey of 2,169 bio-scientists in the UK and G...
# 20  210 students from Berea College, randomly assi...
# 21  Data from the Survey of Professional Forecaste...
# 22  Data from the 'Monitoring the Future' surveys ...
#
#                                          Main_Results  \
# 0   Higher labor income tax rates increase the sha...
# 1   The recentered IV approach yields a 44% smalle...
# 2   Sewer access significantly increases populatio...
# 3   Significant potential for low-cost methane aba...
# 4   The proposed criteria allow for optimal select...
# 5   The paper argues that institutions significant...
# 6   AI technologies may produce various social, ec...
# 7   Firms with higher exposure to Generative AI ex...
# 8   Access to the AI tool increases productivity b...
# 9   AI tools encourage scientists to pursue more s...
# 10  AI's macroeconomic effects are estimated to yi...
# 11  Higher-exposure firms earned excess returns th...
# 12  The effect of AI on jobs is contingent on the ...
# 13  AI adoption increases short-run supply elastic...
# 14  The study finds a universal alignment between ...
# 15  The introduction of AI technologies has led to...
# 16  Female academics, especially those with childr...
# 17  The model shows that small changes in individu...
# 18  The study finds that faculty salaries at publi...
# 19  Sharing is negatively related to competition a...
# 20  The results suggest that studying has a signif...
# 21  Individual forecasts overreact to idiosyncrati...
# 22  The mode of girls' GPA distribution shifted fr...
#
#                                           Effect_Size  \
# 0   5.7% increase in wages associated with a one-s...
# 1   Standard errors from recentered IV are approxi...
# 2   A 1 percentage point increase in sewer share i...
# 3   The potential for low-cost abatement is signif...
# 4   The paper discusses the impact of shrinkage on...
# 5         Not applicable as the paper is theoretical.
# 6         Not applicable as the paper is theoretical.
# 7   Firms in the highest-exposure quintile earned ...
# 8   14% increase in productivity; 34% increase for...
# 9   The model suggests a critical threshold (X*) w...
# 10           Predicted TFP gains are less than 0.53%.
# 11  0.4% daily excess returns, translating to over...
# 12  The model predicts that demand changes can off...
# 13  The model suggests that AI adoption can lead t...
# 14  The Relative Consumption Index (RCI) measures ...
# 15  Regression coefficients indicate a 10% decreas...
# 16  Regression analysis indicates that women with ...
# 17     Not applicable as this is a theoretical model.
# 18  The paper discusses the relative changes in sa...
# 19  Odds ratios for key variables such as competit...
# 20  An extra hour of daily study-time increases fi...
# 21  The degree of information rigidity is estimate...
# 22  The increase in the proportion of girls earnin...
#
#                              Key_Statistical_Measures  \
# 0   p-values, regression coefficients indicating s...
# 1   Minimum detectable effects of recentered IV ar...
# 2    p-values < 0.01, R-squared values not specified.
# 3   Not specified in the abstract, but likely incl...
# 4   The paper includes measures of estimation risk...
# 5         Not applicable as the paper is theoretical.
# 6   Not applicable as the paper does not present e...
# 7   Cumulative abnormal returns, p-values indicati...
# 8   p-values indicating significance of results, s...
# 9   Not applicable; theoretical model without empi...
# 10  Estimates based on theoretical modeling; no sp...
# 11  Statistical significance of excess returns, va...
# 12  Not explicitly stated; focuses on theoretical ...
# 13  Theoretical results; no specific p-values or R...
# 14  RCI values, correlation coefficients indicatin...
# 15                   p-value < 0.05, R-squared = 0.75
# 16  p-values < 0.0001 for significant differences ...
# 17     Not applicable as this is a theoretical model.
# 18  The paper includes discussions on the dispersi...
# 19  R-squared values range from 0.0408 to 0.0829; ...
# 20  p-value for OLS estimates not statistically si...
# 21  p-values indicate significant results; R-squar...
# 22  Significant p-values indicating the importance...
#
#                                           Data_Source  \
# 0   Collection of collective bargaining agreements...
# 1   Data shared by Jonathan Gruber, Ben Sommers, a...
# 2   Census data from Brazil, Colombia, South Afric...
# 3   Various studies and datasets related to methan...
# 4   The data used for empirical application is not...
# 5      Literature review and historical case studies.
# 6       Literature review and theoretical frameworks.
# 7   Market data from Yahoo Finance, LinkedIn profi...
# 8   Data collected from customer support operation...
# 9   Theoretical framework; no specific data source...
# 10  Existing estimates on AI exposure and producti...
# 11  Earnings calls data, firm-level characteristic...
# 12  Historical industry data and economic literature.
# 13  Theoretical framework; no empirical data sourc...
# 14  Microsoft Academic Graph (MAG), Altmetric data...
# 15  U.S. Bureau of Labor Statistics, sector-specif...
# 16  Global survey of academics, with a sample size...
# 17     Theoretical framework; no empirical data used.
# 18  Data collected from institutional reports and ...
# 19  Unique survey of bio-scientists conducted in 2...
# 20  Berea Panel Study, longitudinal data collected...
# 21  Survey of Professional Forecasters (SPF), Fede...
# 22     Monitoring the Future cross-sectional surveys.
#
#                                           Limitations  \
# 0   The study focuses only on Canadian CBAs and ma...
# 1   The paper focuses on a specific setting and ma...
# 2   Challenges in data collection for sewer networ...
# 3   The paper synthesizes existing literature, whi...
# 4   The paper acknowledges potential misspecificat...
# 5   The framework is conceptual and may lack empir...
# 6   The paper does not provide empirical evidence ...
# 7   The study relies on market reactions which may...
# 8   The study does not capture long-term impacts o...
# 9   The model is theoretical and may not capture a...
# 10  The estimates may be exaggerated due to relian...
# 11  The study may not account for all external fac...
# 12  The model may not account for all variables af...
# 13  The model abstracts from certain market imperf...
# 14  The study may not capture all nuances of publi...
# 15  The analysis is limited to the U.S. and may no...
# 16  The response rate was low (3.7%), and the samp...
# 17  The model may not capture all real-world compl...
# 18  The analysis may not account for all variables...
# 19  Response rates were relatively low, and the sa...
# 20  Small sample size limits precision; potential ...
# 21  The study relies on the assumption that the SP...
# 22  The study may not account for all external fac...
#
#                               Implications_for_Policy  \
# 0   Insights derived from union contracts could in...
# 1   The insights may apply to a large class of for...
# 2   Improving sewer access is crucial for urban de...
# 3   Policymakers should consider the cost threshol...
# 4   Practitioners are advised to use an IRF estima...
# 5   The choice of institutions can significantly a...
# 6   Regulation and policies are necessary to redir...
# 7   The findings suggest that policymakers should ...
# 8   Access to generative AI can increase productiv...
# 9   With capable AI tools, funding should prioriti...
# 10  AI's impact on productivity and inequality sug...
# 11  Investors should consider the implications of ...
# 12  Policymakers should consider demand-side facto...
# 13  AI adoption may require policy interventions t...
# 14  The findings suggest that public funding shoul...
# 15  Policies should focus on retraining programs f...
# 16  The findings suggest that institutional polici...
# 17  Policies aimed at reducing segregation should ...
# 18  The findings suggest that policy interventions...
# 19  Policies designed to enhance sharing must be t...
# 20  This work provides direct evidence about an un...
# 21  Surveys cannot be taken as direct proxies of e...
# 22  The findings suggest that educational policies...
#
#                                        Open_Questions Relevance_Likert_Scale  \
# 0   Future research could explore the relationship...                      3
# 1   How can these insights be applied to new and c...                      2
# 2   What are the long-term effects of sewer access...                      2
# 3   Further research is needed on how technologica...                      2
# 4   Future research could explore the application ...                      2
# 5   How can institutions be designed to maximize t...                      2
# 6   What specific regulatory frameworks could effe...                      2
# 7   Future research could explore how Generative A...                      4
# 8   What are the longer-term impacts of generative...                      3
# 9   What specific AI capabilities are most effecti...                      4
# 10  How can AI be directed to create new tasks tha...                      2
# 11  Further research is needed to explore the long...                      3
# 12  What specific demand-side policies can mitigat...                      2
# 13  Further research is needed on the long-term ef...                      3
# 14  Future research could explore how different pu...                      3
# 15  What are the long-term effects of AI on job cr...                      2
# 16  Future research could explore the long-term ef...                      2
# 17  Further research could explore empirical valid...                      2
# 18  Future research could explore the long-term im...                      2
# 19  How can sharing practices be improved in compe...                      2
# 20  Future research could explore the long-term ef...                      2
# 21  Future research could explore the impact of di...                      2
# 22  Further research could explore the impact of i...                      2
#
#                                     Relevance_Reasons
# 0   The paper utilizes text mining techniques to a...
# 1   The paper discusses instrument construction an...
# 2   The paper discusses urbanization and infrastru...
# 3   The paper discusses methodologies for estimati...
# 4   The paper focuses on VAR forecasting and estim...
# 5   The paper discusses the role of technology in ...
# 6   The paper discusses the implications of AI tec...
# 7   The paper discusses the impact of AI on firm b...
# 8   The paper discusses the use of AI tools in enh...
# 9   The paper discusses the impact of AI on resear...
# 10  The paper discusses AI's macroeconomic implica...
# 11  The paper discusses the impact of AI on firm v...
# 12  The paper discusses AI's impact on jobs but do...
# 13  The paper discusses AI adoption in a competiti...
# 14  The paper discusses public use of science and ...
# 15  The paper discusses AI's impact on labor marke...
# 16  The paper discusses the impact of external dis...
# 17  The paper discusses dynamics and trends in seg...
# 18  The paper discusses labor market trends in aca...
# 19  The paper discusses sharing of research result...
# 20  The paper discusses educational outcomes and s...
# 21  The paper discusses biases in survey data, whi...
# 22  The paper discusses educational trends and dis...
#
# [23 rows x 21 columns]

# %%
final_df2 = final_df.drop(columns=['Title_Abstract', 'Conclusion'])

final_df2.to_csv('example_lit_review.tsv', sep = '\t', escapechar='\\')

# %%
import pandas as pd
import json
import concurrent.futures
from tqdm import tqdm

# Task description for generating meta-analysis of academic papers
task_description = (
    "Generate a meta-analysis table for academic papers in economics. "
    "For each paper, extract the following key information:\n"
    "- Paper ID: A unique identifier for the paper (e.g., P001, P002).\n"
    "- Author(s): The authors of the paper.\n"
    "- Year: The publication year of the paper.\n"
    "- Paper Title: The title of the paper.\n"
    "- Journal-Specific ID: The unique identifier for the paper (e.g., DOI, RePEc ID).\n"
    "- Research Question(s) (Quotation): The main research question(s) quoted directly from the paper.\n"
    "- Methodology/Design: A brief description of the methodology or research design.\n"
    "- Key Variables/Concepts: Main variables or concepts explored in the paper. Specify dependent and independant.\n"
    "- Sample/Population: Information about the data/sample (e.g., size, location, time period).\n"
    "- Main Results/Findings: Key results and significant findings.\n"
    "- Effect Size/Impact: A summary of the effect size or impact (e.g., regression coefficients).\n"
    "- Key Statistical Measures: Important statistical measures (e.g., p-values, R-squared).\n"
    "- Data Source: The source of data (e.g., dataset, government sources).\n"
    "- Limitations/Robustness Checks: Summary of limitations or robustness checks.\n"
    "- Implications for Policy/Practice (Quotation): Policy implications quoted from the paper.\n"
    "- Open Questions/Future Research (Quotation): Open questions or suggestions for future research.\n"
    "Additionally, for each paper, evaluate its relevance to the following research question:\n"
    "How does the use of AI-based text mining tools enhance the identification of emerging research trends in academic publications?\n"
    "Provide a Likert scale score (1 to 5) of how relevant the paper is to the research question. "
    "Also, provide a list of reasons why the paper is relevant or not relevant to the research question. and make suggestions of contributions that could be made to open research questions\n"
    "Return the results in the following JSON format:\n"
    "[\n  {\n"
    "    \"paper_id\": \"<paper_id>\",\n"
    "    \"author(s)\": \"<author(s)>\",\n"
    "    \"year\": <year>,\n"
    "    \"paper_title\": \"<paper_title>\",\n"
    "    \"journal_specific_id\": \"<journal_specific_id>\",\n"
    "    \"research_question\": \"<research_question>\",\n"
    "    \"methodology\": \"<methodology>\",\n"
    "    \"key_variables\": \"<key_variables>\",\n"
    "    \"sample_population\": \"<sample_population>\",\n"
    "    \"main_results\": \"<main_results>\",\n"
    "    \"effect_size\": \"<effect_size>\",\n"
    "    \"key_statistical_measures\": \"<key_statistical_measures>\",\n"
    "    \"data_source\": \"<data_source>\",\n"
    "    \"limitations\": \"<limitations>\",\n"
    "    \"implications_for_policy\": \"<implications_for_policy>\",\n"
    "    \"open_questions\": \"<open_questions>\",\n"
    "    \"likert_scale\": <likert_scale>,\n"
    "    \"relevance_reasons\": \"<relevance_reasons>\"\n"
    "  }\n]"
)

def process_chunk(chunk, df):
    """
    Process a DataFrame chunk: build the input, call the API,
    parse the JSON response, and return a DataFrame with the results.
    """
    # Extract relevant details from the chunk.
    paper_urls = chunk['Paper URL'].tolist()
    paper_titles = chunk['Title_Abstract'].tolist()
    paper_conclusions = chunk['Conclusion'].tolist()
    
    # Build input text for the chunk with task description and paper details.
    batch_input = "\n\n".join([
        f"Paper URL: {url}\nTitle & Abstract: {title}\nConclusion: {conclusion}"
        for url, title, conclusion in zip(paper_urls, paper_titles, paper_conclusions)
    ])
    input_text = f"{batch_input}\n\nMeta-Analysis Task Details:\n{task_description}"
    
    # Call your GPT API (modify client call as needed).
    response = client.chat.completions.create(
        model="gpt-4o-mini",  # Adjust model as necessary.
        messages=[
            {"role": "system", "content": "You are an assistant specializing in extracting meta-analysis details from academic papers."},
            {"role": "user", "content": f"{task_description}\n\n{input_text}"}
        ],
        temperature=0
    )
    result_text = response.choices[0].message.content.strip()

    # Remove code block formatting if present.
    if result_text.startswith("```json"):
        result_text = result_text[7:]
    if result_text.endswith("```"):
        result_text = result_text[:-3]
    
    # Parse the JSON response.
    try:
        parsed_data = json.loads(result_text)
        if isinstance(parsed_data, list) and len(parsed_data) == len(paper_urls):
            results = []
            for item in parsed_data:
                # Extract details from the parsed JSON data
                paper_id = item.get('paper_id', 'Unknown')
                author = item.get('author(s)', '')
                year = item.get('year', 'Unknown')
                paper_title = item.get('paper_title', '')
                journal_id = item.get('journal_specific_id', '')
                research_question = item.get('research_question', '')
                methodology = item.get('methodology', '')
                key_variables = item.get('key_variables', '')
                sample_population = item.get('sample_population', '')
                main_results = item.get('main_results', '')
                effect_size = item.get('effect_size', '')
                statistical_measures = item.get('key_statistical_measures', '')
                data_source = item.get('data_source', '')
                limitations = item.get('limitations', '')
                implications_for_policy = item.get('implications_for_policy', '')
                open_questions = item.get('open_questions', '')
                likert_scale = item.get('likert_scale', 'Unknown')  # Default to 'Unknown'
                relevance_reasons = item.get('relevance_reasons', '')  # Default to an empty string
                
                results.append((paper_id, author, year, paper_title, journal_id, research_question, methodology,
                                key_variables, sample_population, main_results, effect_size, statistical_measures,
                                data_source, limitations, implications_for_policy, open_questions, likert_scale, relevance_reasons))
        else:
            # Default values in case the structure doesn't match
            results = [('Unknown', '', 'Unknown', '', '', '', '', '', '', '', '', '', '', '', '', '', '') for _ in paper_urls]
    except json.JSONDecodeError:
        results = [('Unknown', '', 'Unknown', '', '', '', '', "", "", "", "", "", "", "", "", "", "") for _ in paper_urls]
    
    # Create a DataFrame for the results and combine it with the original chunk.
    results_df = pd.DataFrame(results, columns=[
        'Paper_ID', 'Author(s)', 'Year', 'Paper_Title', 'Journal_Specific_ID', 'Research_Question',
        'Methodology', 'Key_Variables', 'Sample_Population', 'Main_Results', 'Effect_Size',
        'Key_Statistical_Measures', 'Data_Source', 'Limitations', 'Implications_for_Policy', 'Open_Questions',
        'Relevance_Likert_Scale', 'Relevance_Reasons'
    ])
    chunk = chunk.reset_index(drop=True)
    combined_df = pd.concat([chunk, results_df], axis=1)
    return combined_df

# Parameters for chunking and parallel processing.
chunk_size = 1  # Number of rows per chunk.
n_workers = 20  # Number of parallel threads.


# Split df (your input DataFrame containing papers) into chunks.
chunks = [df.iloc[i:i + chunk_size] for i in range(0, len(df), chunk_size)]

# Process each chunk in parallel using ThreadPoolExecutor with a progress bar.
with concurrent.futures.ThreadPoolExecutor(max_workers=n_workers) as executor:
    results_dfs = list(
        tqdm(
            executor.map(lambda chunk: process_chunk(chunk, df), chunks),
            total=len(chunks),
            desc="Processing chunks in parallel"
        )
    )

# Concatenate all the chunk DataFrames into one final DataFrame.
final_df = pd.concat(results_dfs, ignore_index=True)

# Display the final result
final_df
# Out:
# Processing chunks in parallel: 100%|████████████| 14/14 [00:13<00:00,  1.01it/s]
#                                             Paper URL  \
# 0   https://www.nber.org/system/files/working_pape...
# 1   https://www.nber.org/system/files/working_pape...
# 2   https://www.nber.org/system/files/working_pape...
# 3   https://www.nber.org/system/files/working_pape...
# 4   https://www.nber.org/system/files/working_pape...
# 5   https://www.nber.org/system/files/working_pape...
# 6   https://www.nber.org/system/files/working_pape...
# 7   https://www.nber.org/system/files/working_pape...
# 8   https://www.nber.org/system/files/working_pape...
# 9   https://www.nber.org/system/files/working_pape...
# 10  https://www.nber.org/system/files/working_pape...
# 11  https://www.nber.org/system/files/working_pape...
# 12  https://www.nber.org/system/files/working_pape...
# 13  https://www.nber.org/system/files/working_pape...
#
#                                        Title_Abstract  \
# 0   NBER WORKING PAPER SERIES\nTHE VALUE OF WORKER...
# 1   NBER WORKING PAPER SERIES\nOPTIMAL FORMULA INS...
# 2   NBER WORKING PAPER SERIES\nSEWERS AND URBANIZA...
# 3   NBER WORKING PAPER SERIES\nMETHANE ABATEMENT C...
# 4   NBER WORKING PAPER SERIES\nMISSPECIFICATION-RO...
# 5   NBER WORKING PAPER SERIES\nINSTITUTIONS, TECHN...
# 6   NBER WORKING PAPER SERIES\nHARMS OF AI\nDaron ...
# 7   NBER WORKING PAPER SERIES\nAI AND FINANCE\nAnd...
# 8   NBER WORKING PAPER SERIES\nGENERATIVE AI AT WO...
# 9   NBER WORKING PAPER SERIES\nA QUEST FOR AI KNOW...
# 10  NBER WORKING PAPER SERIES\nTHE SIMPLE MACROECO...
# 11  NBER WORKING PAPER SERIES\nGENERATIVE AI AND F...
# 12  NBER WORKING PAPER SERIES\nAI AND JOBS: THE RO...
# 13  NBER WORKING PAPER SERIES\nAI ADOPTION IN A CO...
#
#                                            Conclusion Paper_ID  \
# 0   of wages. Our results situate the value of con...     P001
# 1   outcome and the employer-sponsored insurance c...     P001
# 2   The economic logic of cities is simple. We are...     P001
# 3   19 \n REFERENCES  \n \nAgerton, Mark, Gilbert,...     P001
# 4   This Version: February 5, 2025 42\nFigure 6: P...     P001
# 5   new sources of red tape—intended to make a tra...     P001
# 6   example as well. To understand these, let us c...     P001
# 7   corporate finance decisions. For a recent stud...     P001
# 8   7 Conclusion\nAdvancements in AI technologies ...     P001
# 9   The welfare benefits, however, extend far beyo...     P001
# 10  affected groups, because AI-exposed tasks are ...     P001
# 11  V. Conclusion\nMarket prices indicate that the...     P001
# 12  5 increase sufficiently to offset the labor -s...     P001
# 13  the opposite may be the case with the returns ...     P001
#
#                                             Author(s)  Year  \
# 0   Benjamin W. Arold, Elliott Ash, W. Bentley Mac...  2025
# 1                         Kirill Borusyak, Peter Hull  2025
# 2   Sean E. McCulloch, Matthew P. Schaelling, Matt...  2025
# 3   Joseph E. Aldy, Forest L. Reinhardt, Robert N....  2025
# 4           Oriol González-Casasús, Frank Schorfheide  2025
# 5                                      Daron Acemoglu  2025
# 6                                      Daron Acemoglu  2021
# 7                 Andrea L. Eisfeldt, Gregor Schubert  2024
# 8   Erik Brynjolfsson, Danielle Li, Lindsey R. Ray...  2023
# 9                                      Joshua S. Gans  2025
# 10                                     Daron Acemoglu  2024
# 11  Andrea L. Eisfeldt, Gregor Schubert, Miao Ben ...  2023
# 12                                       James Bessen  2018
# 13                                     Joshua S. Gans  2022
#
#                                           Paper_Title  \
# 0   The Value of Worker Rights in Collective Barga...
# 1                         Optimal Formula Instruments
# 2     Sewers and Urbanization in the Developing World
# 3   Methane Abatement Costs in the Oil and Gas Ind...
# 4   Misspecification-Robust Shrinkage and Selectio...
# 5             Institutions, Technology and Prosperity
# 6                                         Harms of AI
# 7                                      AI and Finance
# 8                               Generative AI at Work
# 9                            A Quest for AI Knowledge
# 10                    The Simple Macroeconomics of AI
# 11                      Generative AI and Firm Values
# 12                    AI and Jobs: The Role of Demand
# 13                AI Adoption in a Competitive Market
#
#                   Journal_Specific_ID  \
# 0   http://www.nber.org/papers/w33605
# 1   http://www.nber.org/papers/w33594
# 2        NBER Working Paper No. 33597
# 3   http://www.nber.org/papers/w33564
# 4        NBER Working Paper No. 33474
# 5        NBER Working Paper No. 33442
# 6   http://www.nber.org/papers/w29247
# 7        NBER Working Paper No. 33076
# 8        NBER Working Paper No. 31161
# 9        NBER Working Paper No. 33566
# 10  http://www.nber.org/papers/w32487
# 11       NBER Working Paper No. 31222
# 12  http://www.nber.org/papers/w24235
# 13       NBER Working Paper No. 29996
#
#                                     Research_Question  \
# 0   How do worker rights in collective bargaining ...
# 1   When estimating the effects of treatments defi...
# 2   We investigate the effects of sewer access on ...
# 3   What are the marginal abatement cost functions...
# 4   How can we derive asymptotically unbiased esti...
# 5   How do various types of institutions, market s...
# 6   If AI continues to be deployed along its curre...
# 7   How does Generative AI affect firm values and ...
# 8   What are the impacts of generative AI tools on...
# 9   How does the introduction of artificial intell...
# 10  This paper evaluates claims about large macroe...
# 11  What are the effects of recent advances in Gen...
# 12  The effect of artificial intelligence on jobs ...
# 13  How does AI adoption affect competitive market...
#
#                                           Methodology  ...  \
# 0   The paper employs natural language processing ...  ...
# 1   The paper proposes an algorithm for constructi...  ...
# 2   The paper employs a quasi-experimental design ...  ...
# 3   The paper employs a synthesis of various metho...  ...
# 4   The paper employs Bayesian techniques to estim...  ...
# 5   The paper presents a conceptual framework to a...  ...
# 6   The paper is a theoretical essay discussing po...  ...
# 7   The paper reviews existing literature and prov...  ...
# 8   The paper employs a staggered introduction des...  ...
# 9   Theoretical framework analysis extending Carne...  ...
# 10  The paper employs a task-based model to evalua...  ...
# 11  The study employs a quantitative analysis usin...  ...
# 12  The paper presents a simple model of demand to...  ...
# 13  The paper uses a theoretical model to analyze ...  ...
#
#                                     Sample_Population  \
# 0   30,000 collective bargaining agreements from C...
# 1   The study uses a controlled environment where ...
# 2   Census tract data from Brazil, Colombia, South...
# 3   The study synthesizes findings from various st...
# 4          Estimation sample from 1984:Q1 to 2006:Q4.
# 5   Historical examples from colonialism to modern...
# 6   Theoretical analysis based on existing literat...
# 7   Analysis of firms across various industries po...
# 8   5,179 customer support agents across various l...
# 9   Theoretical model; no empirical data sample sp...
# 10  The analysis is based on existing estimates of...
# 11  U.S. publicly traded companies, focusing on th...
# 12  Historical data from the textile, steel, and a...
# 13  Theoretical model; no empirical data sample sp...
#
#                                          Main_Results  \
# 0   Higher labor income tax rates increase the sha...
# 1   The proposed recentered IV approach yields a 4...
# 2   Sewer access significantly increases populatio...
# 3   The paper finds significant potential for low-...
# 4   The proposed criteria effectively select optim...
# 5   The framework illustrates how institutional di...
# 6   AI technologies may produce various social, ec...
# 7   Generative AI has a significant positive impac...
# 8   Access to the AI tool increases productivity b...
# 9   AI tools encourage scientists to pursue more s...
# 10  AI's macroeconomic effects are estimated to yi...
# 11  Higher-exposure firms earned excess returns th...
# 12  The model predicts that the impact of AI on jo...
# 13  AI adoption can lead to increased supply elast...
#
#                                           Effect_Size  \
# 0   5.7% increase in wages associated with a one-s...
# 1   The minimum detectable effects of recentered I...
# 2   A 1 percentage point increase in sewer access ...
# 3   The paper indicates that cutting methane emiss...
# 4   The paper discusses the impact of shrinkage on...
# 5   Not quantified; qualitative analysis of histor...
# 6         Not applicable as the paper is theoretical.
# 7   Firms in the highest-exposure quintile earned ...
# 8   14% increase in productivity; 34% increase for...
# 9   The model indicates a critical complementarity...
# 10           Predicted TFP gains are less than 0.53%.
# 11  0.4% daily excess returns for higher-exposure ...
# 12  The paper discusses the interaction between pr...
# 13  The model suggests that the effect of AI adopt...
#
#                              Key_Statistical_Measures  \
# 0   Regression coefficients, p-values indicating s...
# 1   Standard errors, minimum detectable effects, p...
# 2   p-values < 0.01, R-squared values indicating s...
# 3   The paper discusses thresholds for cost increa...
# 4   The paper includes measures of estimation unce...
# 5    Not applicable; primarily theoretical framework.
# 6   Not applicable as the paper does not present e...
# 7   p-values, R-squared not explicitly mentioned; ...
# 8   p-values indicating significance of results, R...
# 9   Not applicable; theoretical model without empi...
# 10  No specific p-values or R-squared values are p...
# 11  Statistical significance of excess returns, va...
# 12  The paper does not provide specific p-values o...
# 13  Theoretical results; no specific p-values or R...
#
#                                           Data_Source  \
# 0   Collection of collective bargaining agreements...
# 1       Simulated data from a controlled environment.
# 2   Census data from Brazil, Colombia, South Afric...
# 3   Various studies and reports on methane emissio...
# 4   The data used for empirical application is not...
# 5   Historical records, economic data from various...
# 6       Literature review and theoretical frameworks.
# 7   Market data from Yahoo Finance, LinkedIn profi...
# 8   Data collected from customer support operation...
# 9   Theoretical analysis; no specific data source ...
# 10  Existing estimates on AI exposure and producti...
# 11   Earnings calls data, firm-level characteristics.
# 12  Historical employment and production data from...
# 13  Theoretical framework; no empirical data sourc...
#
#                                           Limitations  \
# 0   The study focuses on a specific geographical a...
# 1   The findings are based on a controlled environ...
# 2   Challenges in data collection due to the under...
# 3   The paper notes that claims of widespread nega...
# 4   The paper acknowledges potential misspecificat...
# 5   The framework is conceptual and may lack empir...
# 6   The paper does not provide empirical evidence ...
# 7   The study relies on existing literature and ma...
# 8   The study does not capture long-term impacts o...
# 9   The model is theoretical and may not capture a...
# 10  The paper acknowledges the speculative nature ...
# 11  The study may not account for all external fac...
# 12  The model may oversimplify complex interaction...
# 13  The model abstracts from certain market imperf...
#
#                               Implications_for_Policy  \
# 0   Insights derived from union contracts could in...
# 1   The insights may apply to a large class of for...
# 2   Improving sewer access is essential for urban ...
# 3   The findings suggest that policymakers should ...
# 4   Practitioners should use an IRF estimation ris...
# 5   The choice of institutions can significantly a...
# 6   Regulation and policies are necessary to redir...
# 7   The integration of Generative AI in firms nece...
# 8   Access to generative AI can increase productiv...
# 9   With capable AI tools, funding should prioriti...
# 10  More favorable wage and inequality effects, as...
# 11  Investors should consider the impact of Genera...
# 12  Policymakers should consider the nature of dem...
# 13  AI adoption should be encouraged as it can enh...
#
#                                        Open_Questions Relevance_Likert_Scale  \
# 0   Future research could explore the relationship...                      3
# 1   How can these insights be applied to other fie...                      2
# 2   What are the long-term impacts of improved sew...                      2
# 3   Future research could explore how technologica...                      2
# 4   Future research could explore the application ...                      2
# 5   How do initial institutional conditions shape ...                      3
# 6   What specific regulatory frameworks could effe...                      2
# 7   Future research should explore how Generative ...                      4
# 8   What are the long-term impacts of generative A...                      3
# 9   What specific AI capabilities are most effecti...                      4
# 10  Forecasting AI’s effects on the macroeconomy i...                      3
# 11  Further research could explore the long-term e...                      3
# 12  How can we better understand the changing natu...                      2
# 13  Further research is needed to explore the long...                      3
#
#                                     Relevance_Reasons
# 0   The paper utilizes text mining techniques to a...
# 1   The paper discusses instrument construction an...
# 2   The paper does not directly address AI-based t...
# 3   The paper discusses methodologies for estimati...
# 4   The paper focuses on VAR forecasting and estim...
# 5   The paper discusses the role of institutions i...
# 6   The paper discusses the implications of AI tec...
# 7   The paper discusses the implications of AI on ...
# 8   The paper discusses the impact of AI tools on ...
# 9   The paper discusses AI's role in reshaping res...
# 10  The paper discusses AI's macroeconomic implica...
# 11  The paper discusses the impact of AI on firm v...
# 12  The paper discusses AI's impact on jobs but do...
# 13  The paper discusses AI adoption in a competiti...
#
# [14 rows x 21 columns]

# %%
final_df2 = final_df.drop(columns=['Title_Abstract', 'Conclusion'])

final_df2.to_csv('example_lit_review.tsv', sep = '\t', escapechar='\\')

# %%
import pandas as pd
import json
import concurrent.futures
from tqdm import tqdm

# Task description for generating meta-analysis of academic papers
task_description = (
    "Generate a meta-analysis table for academic papers in economics. "
    "For each paper, extract the following key information:\n"
    "- Paper ID: A unique identifier for the paper (e.g., P001, P002).\n"
    "- Author(s): The authors of the paper.\n"
    "- Year: The publication year of the paper.\n"
    "- Paper Title: The title of the paper.\n"
    "- Journal-Specific ID: The unique identifier for the paper (e.g., DOI, RePEc ID).\n"
    "- Research Question(s) (Quotation): The main research question(s) quoted directly from the paper.\n"
    "- Methodology/Design: A brief description of the methodology or research design.\n"
    "- Key Variables/Concepts: Main variables or concepts explored in the paper. Specify dependent and independant.\n"
    "- Sample/Population: Information about the data/sample (e.g., size, location, time period).\n"
    "- Main Results/Findings: Key results and significant findings.\n"
    "- Effect Size/Impact: A summary of the effect size or impact (e.g., regression coefficients).\n"
    "- Key Statistical Measures: Important statistical measures (e.g., p-values, R-squared).\n"
    "- Data Source: The source of data (e.g., dataset, government sources).\n"
    "- Limitations/Robustness Checks: Summary of limitations or robustness checks.\n"
    "- Implications for Policy/Practice (Quotation): Policy implications quoted from the paper.\n"
    "- Open Questions/Future Research (Quotation): Open questions or suggestions for future research.\n"
    "Return the results in the following JSON format:\n"
    "[\n  {\n"
    "    \"paper_id\": \"<paper_id>\",\n"
    "    \"author(s)\": \"<author(s)>\",\n"
    "    \"year\": <year>,\n"
    "    \"paper_title\": \"<paper_title>\",\n"
    "    \"journal_specific_id\": \"<journal_specific_id>\",\n"
    "    \"research_question\": \"<research_question>\",\n"
    "    \"methodology\": \"<methodology>\",\n"
    "    \"key_variables\": \"<key_variables>\",\n"
    "    \"sample_population\": \"<sample_population>\",\n"
    "    \"main_results\": \"<main_results>\",\n"
    "    \"effect_size\": \"<effect_size>\",\n"
    "    \"key_statistical_measures\": \"<key_statistical_measures>\",\n"
    "    \"data_source\": \"<data_source>\",\n"
    "    \"limitations\": \"<limitations>\",\n"
    "    \"implications_for_policy\": \"<implications_for_policy>\",\n"
    "    \"open_questions\": \"<open_questions>\"\n"
    "  }\n]"
)

def process_chunk(chunk, df):
    """
    Process a DataFrame chunk: build the input, call the API,
    parse the JSON response, and return a DataFrame with the results.
    """
    # Extract relevant details from the chunk.
    paper_urls = chunk['Paper URL'].tolist()
    paper_titles = chunk['Title_Abstract'].tolist()
    paper_conclusions = chunk['Conclusion'].tolist()
    
    # Build input text for the chunk with task description and paper details.
    batch_input = "\n\n".join([
        f"Paper URL: {url}\nTitle & Abstract: {title}\nConclusion: {conclusion}"
        for url, title, conclusion in zip(paper_urls, paper_titles, paper_conclusions)
    ])
    input_text = f"{batch_input}\n\nMeta-Analysis Task Details:\n{task_description}"
    
    # Call your GPT API (modify client call as needed).
    response = client.chat.completions.create(
        model="gpt-4o-mini",  # Adjust model as necessary.
        messages=[
            {"role": "system", "content": "You are an assistant specializing in extracting meta-analysis details from academic papers."},
            {"role": "user", "content": f"{task_description}\n\n{input_text}"}
        ],
        temperature=0
    )
    result_text = response.choices[0].message.content.strip()

    # Remove code block formatting if present.
    if result_text.startswith("```json"):
        result_text = result_text[7:]
    if result_text.endswith("```"):
        result_text = result_text[:-3]
    
    # Parse the JSON response.
    try:
        parsed_data = json.loads(result_text)
        if isinstance(parsed_data, list) and len(parsed_data) == len(paper_urls):
            results = []
            for item in parsed_data:
                # Extract details from the parsed JSON data
                paper_id = item.get('paper_id', 'Unknown')
                author = item.get('author(s)', '')
                year = item.get('year', 'Unknown')
                paper_title = item.get('paper_title', '')
                journal_id = item.get('journal_specific_id', '')
                research_question = item.get('research_question', '')
                methodology = item.get('methodology', '')
                key_variables = item.get('key_variables', '')
                sample_population = item.get('sample_population', '')
                main_results = item.get('main_results', '')
                effect_size = item.get('effect_size', '')
                statistical_measures = item.get('key_statistical_measures', '')
                data_source = item.get('data_source', '')
                limitations = item.get('limitations', '')
                implications_for_policy = item.get('implications_for_policy', '')
                open_questions = item.get('open_questions', '')
                results.append((paper_id, author, year, paper_title, journal_id, research_question, methodology,
                                key_variables, sample_population, main_results, effect_size, statistical_measures,
                                data_source, limitations, implications_for_policy, open_questions))
        else:
            # Default values in case the structure doesn't match
            results = [('Unknown', '', 'Unknown', '', '', '', '', '', '', '', '', '', '', '', '') for _ in paper_urls]
    except json.JSONDecodeError:
        results = [('Unknown', '', 'Unknown', '', '', '', '', '', '', '', '', '', '', '', '') for _ in paper_urls]
    
    # Create a DataFrame for the results and combine it with the original chunk.
    results_df = pd.DataFrame(results, columns=[
        'Paper_ID', 'Author(s)', 'Year', 'Paper_Title', 'Journal_Specific_ID', 'Research_Question',
        'Methodology', 'Key_Variables', 'Sample_Population', 'Main_Results', 'Effect_Size',
        'Key_Statistical_Measures', 'Data_Source', 'Limitations', 'Implications_for_Policy', 'Open_Questions'
    ])
    chunk = chunk.reset_index(drop=True)
    combined_df = pd.concat([chunk, results_df], axis=1)
    return combined_df

# Parameters for chunking and parallel processing.
chunk_size = 1  # Number of rows per chunk.
n_workers = 10  # Number of parallel threads.


# Split df (your input DataFrame containing papers) into chunks.
chunks = [df.iloc[i:i + chunk_size] for i in range(0, len(df), chunk_size)]

# Process each chunk in parallel using ThreadPoolExecutor with a progress bar.
with concurrent.futures.ThreadPoolExecutor(max_workers=n_workers) as executor:
    results_dfs = list(
        tqdm(
            executor.map(lambda chunk: process_chunk(chunk, df), chunks),
            total=len(chunks),
            desc="Processing chunks in parallel"
        )
    )

# Concatenate all the chunk DataFrames into one final DataFrame.
final_df = pd.concat(results_dfs, ignore_index=True)

# Display the final result
final_df
# Out:
# Processing chunks in parallel:   0%|                     | 0/14 [00:03<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 133
#     132 with concurrent.futures.ThreadPoolExecutor(max_workers=n_workers) as executor:
# --> 133     results_dfs = list(
#     134         tqdm(
#     135             executor.map(lambda chunk: process_chunk(chunk, df), chunks),
#     136             total=len(chunks),
#     137             desc="Processing chunks in parallel"
#     138         )
#     139     )
#     141 # Concatenate all the chunk DataFrames into one final DataFrame.
#
# File ~/miniforge3/lib/python3.10/site-packages/tqdm/std.py:1182, in tqdm.__iter__(self)
#    1181 try:
# -> 1182     for obj in iterable:
#    1183         yield obj
#
# File ~/miniforge3/lib/python3.10/concurrent/futures/_base.py:621, in Executor.map.<locals>.result_iterator()
#     620 if timeout is None:
# --> 621     yield _result_or_cancel(fs.pop())
#     622 else:
#
# File ~/miniforge3/lib/python3.10/concurrent/futures/_base.py:319, in _result_or_cancel(***failed resolving arguments***)
#     318 try:
# --> 319     return fut.result(timeout)
#     320 finally:
#
# File ~/miniforge3/lib/python3.10/concurrent/futures/_base.py:453, in Future.result(self, timeout)
#     451     return self.__get_result()
# --> 453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/miniforge3/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     319 if timeout is None:
# --> 320     waiter.acquire()
#     321     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 132
#     129 chunks = [df.iloc[i:i + chunk_size] for i in range(0, len(df), chunk_size)]
#     131 # Process each chunk in parallel using ThreadPoolExecutor with a progress bar.
# --> 132 with concurrent.futures.ThreadPoolExecutor(max_workers=n_workers) as executor:
#     133     results_dfs = list(
#     134         tqdm(
#     135             executor.map(lambda chunk: process_chunk(chunk, df), chunks),
#    (...)
#     138         )
#     139     )
#     141 # Concatenate all the chunk DataFrames into one final DataFrame.
#
# File ~/miniforge3/lib/python3.10/concurrent/futures/_base.py:649, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     648 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 649     self.shutdown(wait=True)
#     650     return False
#
# File ~/miniforge3/lib/python3.10/concurrent/futures/thread.py:235, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     233 if wait:
#     234     for t in self._threads:
# --> 235         t.join()
#
# File ~/miniforge3/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~/miniforge3/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:
